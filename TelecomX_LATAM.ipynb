# %% [markdown]
# <a href="https://colab.research.google.com/github/FeloCR12/Challenge_Telecom_X/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
#importanto la biblioteca de pandas

import pandas as pd

# %%
#importando el archivo JSON

df = pd.read_json('TelecomX_Data.json')

df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
#se cuenta con información anidad se debe normalizar cada columna

df_customer = pd.json_normalize(df['customer'])
df_phone = pd.json_normalize(df['phone'])
df_internet = pd.json_normalize(df['internet'])
df_account = pd.json_normalize(df['account'])

#unimos los df normalizdos

df_normalizado = pd.concat([df[['customerID', 'Churn']], df_customer, df_phone, df_internet, df_account], axis=1)

df_normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %% [markdown]
# #🔧 Transformación

# %%
#nombres de las columnas y su tipo

df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
#importamos la biblioteca numpy para transformar datos

import numpy as np

# %%
#transformamos el tipo de datos de algunas columnas

df_normalizado['Churn'] = df_normalizado['Churn'].str.strip().replace('', np.nan)
df_normalizado['Charges.Total'] = df_normalizado['Charges.Total'].str.strip().replace('', np.nan).astype(float)

df_normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
#identificamos nuestra columna llave unica

[col for col in df_normalizado.columns if df_normalizado[col].is_unique]
# Out:
# ['customerID']

# %%
#creamos la columna cuenta diaria

df_normalizado['Cuentas_Diarias'] = df_normalizado['Charges.Monthly'] / 30

df_normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %% [markdown]
# #### **Diccionario de datos**
#
# - `customerID`: número de identificación único de cada cliente
# - `Churn`: si el cliente dejó o no la empresa
# - `gender`: género (masculino y femenino)
# - `SeniorCitizen`: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# - `Partner`: si el cliente tiene o no una pareja
# - `Dependents`: si el cliente tiene o no dependientes
# - `tenure`: meses de contrato del cliente
# - `PhoneService`: suscripción al servicio telefónico
# - `MultipleLines`: suscripción a más de una línea telefónica
# - `InternetService`: suscripción a un proveedor de internet
# - `OnlineSecurity`: suscripción adicional de seguridad en línea
# - `OnlineBackup`: suscripción adicional de respaldo en línea
# - `DeviceProtection`: suscripción adicional de protección del dispositivo
# - `TechSupport`: suscripción adicional de soporte técnico, menor tiempo de espera
# - `StreamingTV`: suscripción de televisión por cable
# - `StreamingMovies`: suscripción de streaming de películas
# - `Contract`: tipo de contrato
# - `PaperlessBilling`: si el cliente prefiere recibir la factura en línea
# - `PaymentMethod`: forma de pago
# - `Charges.Monthly`: total de todos los servicios del cliente por mes
# - `Charges.Total`: total gastado por el cliente

# %%
#vamos a estimar cuantas suscripciones tiene el cliente

df_normalizado['Suscurpción_telefono'] = df_normalizado['PhoneService'].apply(lambda x: 1 if x == 'Yes' else 0)
df_normalizado['Suscurpción_internet'] = df_normalizado['InternetService'].apply(lambda x: 0 if x == 'No' else 1)
df_normalizado['Suscurpción_seguridad'] = df_normalizado['OnlineSecurity'].apply(lambda x: 1 if x == 'Yes' else 0)
df_normalizado['Suscurpción_respaldo'] = df_normalizado['OnlineBackup'].apply(lambda x: 1 if x == 'Yes' else 0)
df_normalizado['Suscurpción_proteccion'] = df_normalizado['DeviceProtection'].apply(lambda x: 1 if x == 'Yes' else 0)
df_normalizado['Suscurpción_soporte'] = df_normalizado['TechSupport'].apply(lambda x: 1 if x == 'Yes' else 0)
df_normalizado['Suscurpción_TV'] = df_normalizado['StreamingTV'].apply(lambda x: 1 if x == 'Yes' else 0)
df_normalizado['Suscurpción_peliculas'] = df_normalizado['StreamingMovies'].apply(lambda x: 1 if x == 'Yes' else 0)

df_normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... Charges.Total  \
# ...

# %%
#estimamos el total de sucripciones

df_normalizado['Total_suscripciones'] = df_normalizado[['Suscurpción_telefono'
                                                       ,'Suscurpción_internet'
                                                       ,'Suscurpción_seguridad'
                                                       ,'Suscurpción_respaldo'
                                                       ,'Suscurpción_proteccion'
                                                       ,'Suscurpción_soporte'
                                                       ,'Suscurpción_TV'
                                                       ,'Suscurpción_peliculas'
                                                       ]
                                                      ].sum(axis=1)

df_normalizado
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... Cuentas_Diarias  \
# ...

# %%
df_normalizado.nunique()
# Out:
# customerID                7267
# Churn                        2
# gender                       2
# SeniorCitizen                2
# Partner                      2
# Dependents                   2
# tenure                      73
# PhoneService                 2
# MultipleLines                3
# InternetService              3
# OnlineSecurity               3
# OnlineBackup                 3
# DeviceProtection             3
# TechSupport                  3
# StreamingTV                  3
# StreamingMovies              3
# Contract                     3
# PaperlessBilling             2
# PaymentMethod                4
# Charges.Monthly           1585
# Charges.Total             6530
# Cuentas_Diarias           1585
# Suscurpción_telefono         2
# Suscurpción_internet         2
# Suscurpción_seguridad        2
# Suscurpción_respaldo         2
# Suscurpción_proteccion       2
# Suscurpción_soporte          2
# Suscurpción_TV               2
# Suscurpción_peliculas        2
# ...

# %%
#validamos la información de las columnas

df_normalizado['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
#renombramos algunas columnas

df_normalizado.rename(columns={
    'Churn' : 'Dejo_la_empresa?',
    'gender' : 'Genero',
    'SeniorCitizen' : 'Edad >= 65',
    'Partner' : 'Tiene_Pareja',
    'Dependents' : 'Tiene_Dependientes',
    'tenure' : 'Meses_contrato',
    'Contract' : 'Tipo_contrato',
    'PaperlessBilling' : 'Facturacion_electronica'
}, inplace = True)

df_normalizado
# Out:
#       customerID Dejo_la_empresa?  Genero  Edad >= 65 Tiene_Pareja  \
# 0     0002-ORFBO               No  Female           0          Yes
# 1     0003-MKNFE               No    Male           0           No
# 2     0004-TLHLJ              Yes    Male           0           No
# 3     0011-IGKFF              Yes    Male           1          Yes
# 4     0013-EXCHZ              Yes  Female           1          Yes
# ...          ...              ...     ...         ...          ...
# 7262  9987-LUTYD               No  Female           0           No
# 7263  9992-RRAMN              Yes    Male           0          Yes
# 7264  9992-UJOEL               No    Male           0           No
# 7265  9993-LHIEB               No    Male           0          Yes
# 7266  9995-HOTOH               No    Male           0          Yes
#
#      Tiene_Dependientes  Meses_contrato PhoneService     MultipleLines  \
# 0                   Yes               9          Yes                No
# ...

# %%
df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerID               7267 non-null   object
#  1   Dejo_la_empresa?         7043 non-null   object
#  2   Genero                   7267 non-null   object
#  3   Edad >= 65               7267 non-null   int64
#  4   Tiene_Pareja             7267 non-null   object
#  5   Tiene_Dependientes       7267 non-null   object
#  6   Meses_contrato           7267 non-null   int64
#  7   PhoneService             7267 non-null   object
#  8   MultipleLines            7267 non-null   object
#  9   InternetService          7267 non-null   object
#  10  OnlineSecurity           7267 non-null   object
#  11  OnlineBackup             7267 non-null   object
#  12  DeviceProtection         7267 non-null   object
#  13  TechSupport              7267 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
#calculemos la distribución de los servicios contratados y su %

cant_suscripciones = df_normalizado['Total_suscripciones'].value_counts().sort_index()

df_cant_suscripciones = cant_suscripciones.to_frame(name = 'CantidadClientes')

df_cant_suscripciones['Porcentaje'] = (df_cant_suscripciones['CantidadClientes'] / df_cant_suscripciones['CantidadClientes'].sum() * 100).round(2)

df_cant_suscripciones
# Out:
#                      CantidadClientes  Porcentaje
# Total_suscripciones
# 1                                1662       22.87
# 2                                 759       10.44
# 3                                1024       14.09
# 4                                1067       14.68
# 5                                1092       15.03
# 6                                 858       11.81
# 7                                 539        7.42
# 8                                 266        3.66

# %%
#mediana de suscripciones

df_normalizado['Total_suscripciones'].mean().round(2)
# Out:
# np.float64(3.72)

# %%
#mediana de meses de contrato

df_normalizado['Meses_contrato'].mean().round(2)
# Out:
# np.float64(32.35)

# %%
#mediana de pago mensual

df_normalizado['Charges.Monthly'].mean().round(2)
# Out:
# np.float64(64.72)

# %%
# % por genero

(df_normalizado['Genero'].value_counts() / df_cant_suscripciones['CantidadClientes'].sum() * 100).round(2)
# Out:
# Genero
# Male      50.57
# Female    49.43
# Name: count, dtype: float64

# %%
# % por tipo de contrato

(df_normalizado['Tipo_contrato'].value_counts() / df_cant_suscripciones['CantidadClientes'].sum() * 100).round(2)
# Out:
# Tipo_contrato
# Month-to-month    55.11
# Two year          23.99
# One year          20.90
# Name: count, dtype: float64

# %%
# % son dependientes

(df_normalizado['Tiene_Dependientes'].value_counts() / df_cant_suscripciones['CantidadClientes'].sum() * 100).round(2)
# Out:
# Tiene_Dependientes
# No     69.99
# Yes    30.01
# Name: count, dtype: float64

# %%
# % de abandono

(df_normalizado['Dejo_la_empresa?'].value_counts() / df_cant_suscripciones['CantidadClientes'].sum() * 100).round(2)
# Out:
# Dejo_la_empresa?
# No     71.20
# Yes    25.72
# Name: count, dtype: float64

# %%
#importamos la biblioteca para los graficos

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#grafico pie de abandono

datos = df_normalizado['Dejo_la_empresa?'].value_counts()
labels = ['No', 'Si']
sizes = datos.values
colors = sns.color_palette('pastel')[0:5]

plt.figure(figsize=(7,7))
plt.pie(sizes, labels=labels, colors=colors, autopct='%.0f%%', textprops={'fontsize': 20}, startangle = 90)

plt.title('Distribución de abandono de clientes', fontsize = 24, fontweight = 'bold')
plt.ylabel('')
plt.show()

# %%
# relación entre cantidad de servicios y abandono

df_normalizado.groupby('Dejo_la_empresa?')['Total_suscripciones'].describe()
# Out:
#                    count      mean       std  min  25%  50%  75%  max
# Dejo_la_empresa?
# No                5174.0  3.763239  2.250114  1.0  1.0  4.0  6.0  8.0
# Yes               1869.0  3.616907  1.609944  1.0  2.0  3.0  5.0  8.0

# %%
# relación entre dependiente y abandono

df_normalizado.groupby('Dejo_la_empresa?')['Tiene_Dependientes'].describe()
# Out:
#                  count unique top  freq
# Dejo_la_empresa?
# No                5174      2  No  3390
# Yes               1869      2  No  1543

# %%
# relación entre genero y abandono

df_normalizado.groupby('Dejo_la_empresa?')['Genero'].describe()
# Out:
#                  count unique     top  freq
# Dejo_la_empresa?
# No                5174      2    Male  2625
# Yes               1869      2  Female   939

# %%
# relación entre metodo de pago y abandono

df_normalizado.groupby('Dejo_la_empresa?')['PaymentMethod'].describe()
# Out:
#                  count unique               top  freq
# Dejo_la_empresa?
# No                5174      4      Mailed check  1304
# Yes               1869      4  Electronic check  1071

# %%
# Distribución de abandono por metodo de pago

metodo_pago = (pd.crosstab(df_normalizado['PaymentMethod'], df_normalizado['Dejo_la_empresa?'], normalize = 'index') * 100).round(2)
metodo_pago.plot(kind = 'bar', figsize = (10,6), color = sns.color_palette('pastel'))

plt.title('Distribución de abandono por método de pago', fontsize = 24, fontweight = 'bold')
plt.ylabel('Porcentaje')
plt.xlabel('Metodo de pago')
plt.xticks(rotation = 0)
plt.legend(title = 'Dejo la empresa?')
plt.tight_layout()
plt.show()

# %%
#Distribución de abandono por

metodo_pago = (pd.crosstab(df_normalizado['Tipo_contrato'], df_normalizado['Dejo_la_empresa?'], normalize = 'index') * 100).round(2)
metodo_pago.plot(kind = 'bar', figsize = (10,6), color = sns.color_palette('pastel'))

plt.title('Distribución de abandono por tipo de contrato', fontsize = 24, fontweight = 'bold')
plt.ylabel('Porcentaje')
plt.xlabel('Tipo de contrato')
plt.xticks(rotation = 0)
plt.legend(title = 'Dejo la empresa?')
plt.tight_layout()
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##**Introducción**
#
# Para una organización comercial, los clientes representan un componente fundamental de su dinámica. Por ello, los equipos de estrategia constantemente desarrollan iniciativas y campañas orientadas tanto a la atracción de nuevos clientes como a la retención del portafolio actual.
#
# Para que estas estrategias sean realmente efectivas, es indispensable comprender las necesidades y puntos de dolor de los clientes, lo cual puede lograrse mediante el análisis de sus datos.
#
# La compañía TELECOM X no es la excepción. Por ello, a través del análisis de un conjunto de datos que contiene características demográficas y detalles sobre los productos contratados, se busca identificar los factores que pueden influir en la permanencia de un cliente.
#
#
#
# ---
#
#
# ##**Limpieza y Tratamiento de Datos**
#
# Para realizar el análisis de la información, se llevó a cabo una serie de pasos que se detallan a continuación:
#
# 1. Se importó el archivo TelecomX_Data.json para ser trabajado en una herramienta con Python.
#
# 2. Se normalizó la información, ya que el archivo contenía columnas con datos anidados.
#
# 3. Se analizó la estructura de las columnas, considerando aspectos como:
# * Tipo de dato.
# * Presencia de valores nulos o caracteres especiales que pudieran afectar cálculos posteriores.
#
# 4. Se validó que el campo customerID fuera único, con el fin de emplearlo como clave principal.
#
# 5. Se crearon columnas adicionales para enriquecer el análisis, tales como:
# * Costo por día de servicios.
# * Cantidad de suscripciones por cliente.
#
# 6. Para facilitar la comprensión, se renombraron algunas columnas con nombres más claros y descriptivos.
#
#
#
# ---
#
#
# ##**Análisis Exploratorio de Datos**
#
# Una vez estructurada la información, se procedió a realizar algunas estimaciones que permitieran al equipo identificar patrones de comportamiento entre los clientes. Entre los principales hallazgos se destacan los siguientes:
#
# * El 62% de los clientes contrata cuatro o menos productos.
#
#
#
# * El 55% de los clientes cuenta con contratos mes a mes.
#
# ![image.png](data:image/png;base64,...)
#
# * El 70% no tiene ningún dependiente (esposo(a) o hijos).
#
# * La compañía presenta una tasa de abandono aproximada del 27%.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ---
#
#
# ##**Conclusiones**
#
#
# A partir del análisis cruzado de las variables y sus correlaciones, fue posible identificar los siguientes hallazgos relevantes:
#
# 1. Los clientes sin dependientes (esposo(a) o hijos) son más propensos a abandonar la compañía.
#
# 2. En promedio, los clientes que permanecen tienen más servicios contratados que aquellos que se dan de baja. Esto sugiere que la cantidad de servicios contratados podría estar relacionada con la retención: a mayor cantidad de servicios, mayor probabilidad de permanencia.
#
# 3. El método de pago parece tener una relación con la tasa de abandono. Los clientes que utilizan cheque electrónico (Electronic check) presentan una mayor tasa de deserción, mientras que quienes usan métodos como cheque por correo (Mailed check) o tarjeta de crédito/débito automática muestran mejores niveles de retención.
#
# 4. Los contratos a corto plazo (mes a mes) reflejan un menor compromiso con la compañía, lo cual se traduce en una mayor propensión al abandono.
#
#
#
# ---
#
#
# ##**Recomendaciones**
#
# Con base en los resultados del análisis, se proponen las siguientes acciones para mejorar la retención de clientes en la compañía TELECOM X:
#
# 1. Diseñar ofertas personalizadas para clientes sin dependientes, en donde se puedad ofrecer paquetes personalizados, con beneficios exclusivos.
#
# 2. Impulsar combos de servicios con precios especiales, que pueden ir mejorando entre más servicios se adquiera.
#
# 3. Revisar y optimizar los métodos de pago ofrecidos, incentivando principalmente métodos de pago automáticos (como tarjetas o débitos directos), ofreciendo beneficios como acumulación de puntos o facilidad en la gestión de pagos.
#
# 4. Impulsar contratos de mayor duración(anuales o semestrales) mediante incentivos económicos o beneficios adicionales, como descuentos por fidelidad o regalos promocionales de ciertos servicios.
#
# 5. Desarrollar un plan de alertas tempranas con modelos predictivos que alerten sobre clientes con alto riesgo de abandono, permitiendo implementar acciones proactivas (contacto personalizado, encuestas de satisfacción, campañas de retención).
